# %%
array = ["水", "金", "地", "火", "木", "土", "天", "海", "冥"]
# リストを2倍にしてからループ
for item in array * 2:
    print(item)
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥

# %%
array = ["水", "金", "地", "火", "木", "土", "天", "海", "冥"]

# リストを2倍にしてからループ
i = 0
double_array = array * 2
while i < len(double_array):
    print(double_array[i])
    i += 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
